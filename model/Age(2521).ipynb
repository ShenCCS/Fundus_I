# %%
import torch
import models_vit
import torch.nn as nn
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, auc

from pathlib import  Path
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from util.pos_embed import interpolate_pos_embed
from timm.models.layers import trunc_normal_
from torch.nn import Linear,ReLU,CrossEntropyLoss

# %%
# call the model
model_R = models_vit.__dict__['vit_large_patch16'](
    num_classes=2,
    drop_path_rate=0.2,
    global_pool=True,
)

# load RETFound weights
checkpoint = torch.load('RETFound_cfp_weights.pth', map_location='cpu')
checkpoint_model = checkpoint['model']
state_dict = model_R.state_dict()

for k in ['head.weight', 'head.bias']:
    if k in checkpoint_model and checkpoint_model[k].shape != state_dict[k].shape:
        print(f"Removing key {k} from pretrained checkpoint")
        del checkpoint_model[k]

# interpolate position embedding
interpolate_pos_embed(model_R, checkpoint_model)

# load pre-trained model
msg = model_R.load_state_dict(checkpoint_model, strict=False)

assert set(msg.missing_keys) == {'head.weight', 'head.bias', 'fc_norm.weight', 'fc_norm.bias'}

# manually initialize fc layer
trunc_normal_(model_R.head.weight, std=2e-5)

#print("Model = %s" % str(model_R))
# Out:
# Parameter containing:
# tensor([[ 1.1479e-05, -8.7750e-06,  1.0286e-05,  ...,  3.4504e-05,
#          -1.6457e-06, -3.7816e-05],
#         [-9.6383e-06,  2.7171e-05,  1.3580e-06,  ..., -4.3631e-06,
#           1.2033e-05,  9.8964e-06]], requires_grad=True)

# %%
data_transform = transforms.Compose([transforms.Resize((224, 224)),transforms.ToTensor()])
# train_data = datasets.ImageFolder('/home/john/network/RETFound/RETFound_MAE-main/data/Gender/', transform=data_transform)
train_data = datasets.ImageFolder('/home/cluster/Fundus/RETFound_MAE-main/data/Age/', transform=data_transform)

total_data = len(train_data)
split = int(0.8 * total_data)

# %%
training_data, validation_data = torch.utils.data.random_split(train_data,[split,total_data - split])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_R.to(device)

train_loader = torch.utils.data.DataLoader(training_data, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(validation_data, batch_size=32, shuffle=True)


criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)
optimizer = optim.SGD(model_R.parameters(), lr=0.001, momentum=0.9)


num_epochs = 150
training_loss = []  
validation_loss = []
train_acc = []
validatoin_acc = []

#Training

for epoch in range(num_epochs):
    model_R.train()
    running_train_loss = 0.0
    train_correct = 0
    train_total = 0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model_R(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_train_loss / len(train_loader)
    train_accuary = train_correct / train_total
    training_loss.append(train_loss)
    train_acc.append(train_accuary)


#Validation

    model_R.eval()
    running_val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for i,data in enumerate(val_loader,0):
            inputs,labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_R(inputs)
            val_loss = criterion(outputs,labels)
            running_val_loss += val_loss.item()

            _,predicted = torch.max(outputs,1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()


    val_loss = running_val_loss / len(val_loader)
    val_accuracy = val_correct / val_total
    validation_loss.append(val_loss)
    validatoin_acc.append(val_accuracy)
    

    print(f"Epoch {epoch+1}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuary*100:.2f}%, Validatoin Loss: {val_loss:.4f}, Validatoin Accuracy: {val_accuracy*100:.2f}%")
    if (epoch + 1) %  10 == 0:
        torch.save(model_R.state_dict(),f"Age_model_checkpoint_epoch_{epoch + 1}.pth")

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_loss,label = 'Training')
plt.plot(range(1, num_epochs + 1), validation_loss,label = 'Validation')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_acc,color='g',label = 'Training')
plt.plot(range(1, num_epochs + 1), validatoin_acc,color='r',label = 'Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 0.6470, Training Accuracy: 62.00%, Validatoin Loss: 0.5575, Validatoin Accuracy: 72.67%
# Epoch 2, Training Loss: 0.5778, Training Accuracy: 70.63%, Validatoin Loss: 0.5661, Validatoin Accuracy: 71.29%
# Epoch 3, Training Loss: 0.5469, Training Accuracy: 72.02%, Validatoin Loss: 0.4949, Validatoin Accuracy: 78.42%
# Epoch 4, Training Loss: 0.5181, Training Accuracy: 75.00%, Validatoin Loss: 0.4907, Validatoin Accuracy: 78.81%
# Epoch 5, Training Loss: 0.5279, Training Accuracy: 74.11%, Validatoin Loss: 0.5412, Validatoin Accuracy: 73.07%
# Epoch 6, Training Loss: 0.4774, Training Accuracy: 77.43%, Validatoin Loss: 0.4282, Validatoin Accuracy: 80.79%
# Epoch 7, Training Loss: 0.4464, Training Accuracy: 78.67%, Validatoin Loss: 0.4353, Validatoin Accuracy: 80.00%
# Epoch 8, Training Loss: 0.4242, Training Accuracy: 81.45%, Validatoin Loss: 0.4141, Validatoin Accuracy: 81.19%
# Epoch 9, Training Loss: 0.4594, Training Accuracy: 77.93%, Validatoin Loss: 0.5370, Validatoin Accuracy: 74.06%
# Epoch 10, Training Loss: 0.4186, Training Accuracy: 80.65%, Validatoin Loss: 0.3936, Validatoin Accuracy: 83.17%
# Epoch 11, Training Loss: 0.3866, Training Accuracy: 82.69%, Validatoin Loss: 0.5722, Validatoin Accuracy: 73.66%
# Epoch 12, Training Loss: 0.3937, Training Accuracy: 82.24%, Validatoin Loss: 0.3521, Validatoin Accuracy: 85.15%
# Epoch 13, Training Loss: 0.3742, Training Accuracy: 84.38%, Validatoin Loss: 0.3605, Validatoin Accuracy: 84.75%
# Epoch 14, Training Loss: 0.3385, Training Accuracy: 84.57%, Validatoin Loss: 0.3800, Validatoin Accuracy: 83.17%
# Epoch 15, Training Loss: 0.3250, Training Accuracy: 85.57%, Validatoin Loss: 0.3373, Validatoin Accuracy: 86.34%
# Epoch 16, Training Loss: 0.3219, Training Accuracy: 85.37%, Validatoin Loss: 0.3116, Validatoin Accuracy: 86.34%
# Epoch 17, Training Loss: 0.2999, Training Accuracy: 87.05%, Validatoin Loss: 0.2758, Validatoin Accuracy: 86.93%
# Epoch 132, Training Loss: 0.0115, Training Accuracy: 99.60%, Validatoin Loss: 0.3930, Validatoin Accuracy: 92.67%
# Epoch 133, Training Loss: 0.0071, Training Accuracy: 99.80%, Validatoin Loss: 0.4842, Validatoin Accuracy: 92.28%
# Epoch 134, Training Loss: 0.0033, Training Accuracy: 99.90%, Validatoin Loss: 0.4937, Validatoin Accuracy: 91.29%
# Epoch 135, Training Loss: 0.0119, Training Accuracy: 99.60%, Validatoin Loss: 0.5430, Validatoin Accuracy: 89.11%
# Epoch 136, Training Loss: 0.0088, Training Accuracy: 99.80%, Validatoin Loss: 0.4335, Validatoin Accuracy: 92.87%
# Epoch 137, Training Loss: 0.0123, Training Accuracy: 99.75%, Validatoin Loss: 0.4593, Validatoin Accuracy: 92.48%
# Epoch 138, Training Loss: 0.0076, Training Accuracy: 99.75%, Validatoin Loss: 0.4818, Validatoin Accuracy: 92.48%
# Epoch 139, Training Loss: 0.0087, Training Accuracy: 99.70%, Validatoin Loss: 0.3862, Validatoin Accuracy: 92.87%
# Epoch 140, Training Loss: 0.0143, Training Accuracy: 99.65%, Validatoin Loss: 0.3695, Validatoin Accuracy: 92.87%
# Epoch 141, Training Loss: 0.0084, Training Accuracy: 99.75%, Validatoin Loss: 0.5422, Validatoin Accuracy: 89.70%
# Epoch 142, Training Loss: 0.0173, Training Accuracy: 99.26%, Validatoin Loss: 0.5299, Validatoin Accuracy: 89.11%
# Epoch 143, Training Loss: 0.0082, Training Accuracy: 99.75%, Validatoin Loss: 0.4348, Validatoin Accuracy: 90.10%
# Epoch 144, Training Loss: 0.0062, Training Accuracy: 99.85%, Validatoin Loss: 0.4151, Validatoin Accuracy: 92.28%
# Epoch 145, Training Loss: 0.0104, Training Accuracy: 99.65%, Validatoin Loss: 0.5968, Validatoin Accuracy: 90.50%
# Epoch 146, Training Loss: 0.0099, Training Accuracy: 99.45%, Validatoin Loss: 0.4834, Validatoin Accuracy: 91.49%
# Epoch 147, Training Loss: 0.0060, Training Accuracy: 99.75%, Validatoin Loss: 0.4420, Validatoin Accuracy: 91.88%
# Epoch 148, Training Loss: 0.0176, Training Accuracy: 99.45%, Validatoin Loss: 0.5272, Validatoin Accuracy: 91.68%
# Epoch 149, Training Loss: 0.0145, Training Accuracy: 99.60%, Validatoin Loss: 0.5506, Validatoin Accuracy: 88.71%
# Epoch 150, Training Loss: 0.0056, Training Accuracy: 99.90%, Validatoin Loss: 0.3813, Validatoin Accuracy: 93.07%

# %%
model_R.eval()
all_labels = [] 
all_scores = []  

with torch.no_grad():
    for i, data in enumerate(val_loader, 0):  # val_loader or train_loader
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model_R(inputs)

        all_labels.extend(labels.cpu().numpy())  # real label
        all_scores.extend(outputs[:, 1].cpu().numpy())  # model predict score

# Calculate AUC
fpr, tpr, thresholds = roc_curve(all_labels, all_scores)
auroc = auc(fpr, tpr)

print(f"AUROC: {auroc:.4f}")

# draw ROC
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUROC = {auroc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# AUROC: 0.9755
