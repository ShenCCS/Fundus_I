# %%
import torch
import models_vit
import torch.nn as nn
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, auc

from pathlib import  Path
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from util.pos_embed import interpolate_pos_embed
from timm.models.layers import trunc_normal_
from torch.nn import Linear,ReLU,CrossEntropyLoss

# %%
# call the model
model_R = models_vit.__dict__['vit_large_patch16'](
    num_classes=2,
    drop_path_rate=0.2,
    global_pool=True,
)

# load RETFound weights
checkpoint = torch.load('RETFound_cfp_weights.pth', map_location='cpu')
checkpoint_model = checkpoint['model']
state_dict = model_R.state_dict()

for k in ['head.weight', 'head.bias']:
    if k in checkpoint_model and checkpoint_model[k].shape != state_dict[k].shape:
        print(f"Removing key {k} from pretrained checkpoint")
        del checkpoint_model[k]

# interpolate position embedding
interpolate_pos_embed(model_R, checkpoint_model)

# load pre-trained model
msg = model_R.load_state_dict(checkpoint_model, strict=False)

assert set(msg.missing_keys) == {'head.weight', 'head.bias', 'fc_norm.weight', 'fc_norm.bias'}

# manually initialize fc layer
trunc_normal_(model_R.head.weight, std=2e-5)

#print("Model = %s" % str(model_R))
# Out:
# Parameter containing:
# tensor([[-1.3290e-05,  2.0381e-05,  1.1072e-05,  ...,  2.5843e-05,
#           2.8881e-05,  3.8763e-05],
#         [ 2.2316e-05, -2.4275e-05, -2.4712e-05,  ...,  6.6915e-06,
#          -4.2313e-05, -1.3997e-05]], requires_grad=True)

# %%
data_transform = transforms.Compose([transforms.Resize((224, 224)),transforms.ToTensor()])
train_data = datasets.ImageFolder('/home/john/network/RETFound/RETFound_MAE-main/data/BMI/', transform=data_transform)
# train_data = datasets.ImageFolder('/home/cluster/Fundus/RETFound_MAE-main/data/BMI/', transform=data_transform)

total_data = len(train_data)
split = int(0.8 * total_data)

# %%
training_data, validation_data = torch.utils.data.random_split(train_data,[split,total_data - split])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_R.to(device)

train_loader = torch.utils.data.DataLoader(training_data, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(validation_data, batch_size=32, shuffle=True)


criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)
optimizer = optim.SGD(model_R.parameters(), lr=0.001, momentum=0.9)


num_epochs = 150
training_loss = []  
validation_loss = []
train_acc = []
validatoin_acc = []

#Training

for epoch in range(num_epochs):
    model_R.train()
    running_train_loss = 0.0
    train_correct = 0
    train_total = 0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model_R(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_train_loss / len(train_loader)
    train_accuary = train_correct / train_total
    training_loss.append(train_loss)
    train_acc.append(train_accuary)


#Validation

    model_R.eval()
    running_val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for i,data in enumerate(val_loader,0):
            inputs,labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_R(inputs)
            val_loss = criterion(outputs,labels)
            running_val_loss += val_loss.item()

            _,predicted = torch.max(outputs,1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()


    val_loss = running_val_loss / len(val_loader)
    val_accuracy = val_correct / val_total
    validation_loss.append(val_loss)
    validatoin_acc.append(val_accuracy)
    

    print(f"Epoch {epoch+1}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuary*100:.2f}%, Validatoin Loss: {val_loss:.4f}, Validatoin Accuracy: {val_accuracy*100:.2f}%")


plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_loss,label = 'Training')
plt.plot(range(1, num_epochs + 1), validation_loss,label = 'Validation')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_acc,color='g',label = 'Training')
plt.plot(range(1, num_epochs + 1), validatoin_acc,color='r',label = 'Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 0.6992, Training Accuracy: 57.99%, Validatoin Loss: 0.7310, Validatoin Accuracy: 39.60%
# Epoch 2, Training Loss: 0.6859, Training Accuracy: 58.43%, Validatoin Loss: 0.6603, Validatoin Accuracy: 60.40%
# Epoch 3, Training Loss: 0.6833, Training Accuracy: 59.23%, Validatoin Loss: 0.6530, Validatoin Accuracy: 61.19%
# Epoch 4, Training Loss: 0.6871, Training Accuracy: 59.38%, Validatoin Loss: 0.6607, Validatoin Accuracy: 63.17%
# Epoch 5, Training Loss: 0.6723, Training Accuracy: 60.62%, Validatoin Loss: 0.6466, Validatoin Accuracy: 63.17%
# Epoch 6, Training Loss: 0.6966, Training Accuracy: 58.53%, Validatoin Loss: 0.8060, Validatoin Accuracy: 60.59%
# Epoch 7, Training Loss: 0.6786, Training Accuracy: 61.31%, Validatoin Loss: 0.6681, Validatoin Accuracy: 59.80%
# Epoch 8, Training Loss: 0.6608, Training Accuracy: 61.26%, Validatoin Loss: 0.6589, Validatoin Accuracy: 61.58%
# Epoch 9, Training Loss: 0.6602, Training Accuracy: 63.19%, Validatoin Loss: 0.7046, Validatoin Accuracy: 61.19%
# Epoch 10, Training Loss: 0.6462, Training Accuracy: 63.24%, Validatoin Loss: 0.6734, Validatoin Accuracy: 62.57%
# Epoch 11, Training Loss: 0.6604, Training Accuracy: 62.80%, Validatoin Loss: 0.7014, Validatoin Accuracy: 61.98%
# Epoch 12, Training Loss: 0.6597, Training Accuracy: 63.99%, Validatoin Loss: 0.6503, Validatoin Accuracy: 64.36%
# Epoch 13, Training Loss: 0.6464, Training Accuracy: 63.59%, Validatoin Loss: 0.7533, Validatoin Accuracy: 54.65%
# Epoch 14, Training Loss: 0.6401, Training Accuracy: 64.38%, Validatoin Loss: 0.6745, Validatoin Accuracy: 62.18%
# Epoch 15, Training Loss: 0.6479, Training Accuracy: 63.29%, Validatoin Loss: 0.7370, Validatoin Accuracy: 61.58%
# Epoch 16, Training Loss: 0.6401, Training Accuracy: 63.59%, Validatoin Loss: 0.6239, Validatoin Accuracy: 66.53%
# Epoch 17, Training Loss: 0.6309, Training Accuracy: 64.58%, Validatoin Loss: 0.6252, Validatoin Accuracy: 64.75%
# Epoch 18, Training Loss: 0.6183, Training Accuracy: 66.42%, Validatoin Loss: 0.7125, Validatoin Accuracy: 61.98%
# Epoch 19, Training Loss: 0.6553, Training Accuracy: 63.14%, Validatoin Loss: 0.6434, Validatoin Accuracy: 65.15%
# Epoch 20, Training Loss: 0.6386, Training Accuracy: 64.38%, Validatoin Loss: 0.6395, Validatoin Accuracy: 65.54%
# Epoch 21, Training Loss: 0.6344, Training Accuracy: 64.53%, Validatoin Loss: 0.7177, Validatoin Accuracy: 63.37%
# Epoch 22, Training Loss: 0.6309, Training Accuracy: 66.32%, Validatoin Loss: 0.6196, Validatoin Accuracy: 67.13%
# Epoch 23, Training Loss: 0.5989, Training Accuracy: 66.96%, Validatoin Loss: 0.6057, Validatoin Accuracy: 69.90%
# Epoch 24, Training Loss: 0.5920, Training Accuracy: 69.05%, Validatoin Loss: 0.5980, Validatoin Accuracy: 68.51%
# Epoch 25, Training Loss: 0.6207, Training Accuracy: 67.06%, Validatoin Loss: 0.7285, Validatoin Accuracy: 63.76%
# Epoch 26, Training Loss: 0.5877, Training Accuracy: 69.84%, Validatoin Loss: 0.6364, Validatoin Accuracy: 66.14%
# Epoch 27, Training Loss: 0.5808, Training Accuracy: 69.84%, Validatoin Loss: 0.5959, Validatoin Accuracy: 66.53%
# Epoch 28, Training Loss: 0.5571, Training Accuracy: 72.17%, Validatoin Loss: 0.5762, Validatoin Accuracy: 70.89%
# Epoch 29, Training Loss: 0.5684, Training Accuracy: 71.38%, Validatoin Loss: 0.5976, Validatoin Accuracy: 66.93%
# Epoch 30, Training Loss: 0.5578, Training Accuracy: 72.37%, Validatoin Loss: 0.5588, Validatoin Accuracy: 69.90%
# Epoch 31, Training Loss: 0.5370, Training Accuracy: 72.77%, Validatoin Loss: 0.5488, Validatoin Accuracy: 70.50%
# Epoch 32, Training Loss: 0.5182, Training Accuracy: 73.86%, Validatoin Loss: 0.5396, Validatoin Accuracy: 72.28%
# Epoch 33, Training Loss: 0.5011, Training Accuracy: 75.45%, Validatoin Loss: 0.5891, Validatoin Accuracy: 65.74%
# Epoch 34, Training Loss: 0.5022, Training Accuracy: 76.44%, Validatoin Loss: 0.5232, Validatoin Accuracy: 73.07%
# Epoch 35, Training Loss: 0.4958, Training Accuracy: 75.74%, Validatoin Loss: 0.5376, Validatoin Accuracy: 74.85%
# Epoch 36, Training Loss: 0.4833, Training Accuracy: 76.49%, Validatoin Loss: 0.5238, Validatoin Accuracy: 71.09%
# Epoch 37, Training Loss: 0.4675, Training Accuracy: 77.78%, Validatoin Loss: 0.4834, Validatoin Accuracy: 75.84%
# Epoch 38, Training Loss: 0.4783, Training Accuracy: 77.03%, Validatoin Loss: 0.4960, Validatoin Accuracy: 75.64%
# Epoch 39, Training Loss: 0.4391, Training Accuracy: 80.26%, Validatoin Loss: 0.5282, Validatoin Accuracy: 72.48%
# Epoch 40, Training Loss: 0.4194, Training Accuracy: 80.21%, Validatoin Loss: 0.4907, Validatoin Accuracy: 73.86%
# Epoch 41, Training Loss: 0.4134, Training Accuracy: 80.70%, Validatoin Loss: 0.4420, Validatoin Accuracy: 76.24%
# Epoch 42, Training Loss: 0.3791, Training Accuracy: 83.23%, Validatoin Loss: 0.4594, Validatoin Accuracy: 77.43%
# Epoch 43, Training Loss: 0.3863, Training Accuracy: 82.24%, Validatoin Loss: 0.4615, Validatoin Accuracy: 78.81%
# Epoch 44, Training Loss: 0.3732, Training Accuracy: 82.89%, Validatoin Loss: 0.5056, Validatoin Accuracy: 77.43%
# Epoch 45, Training Loss: 0.3790, Training Accuracy: 83.23%, Validatoin Loss: 0.4430, Validatoin Accuracy: 81.19%
# Epoch 46, Training Loss: 0.3400, Training Accuracy: 84.47%, Validatoin Loss: 0.4677, Validatoin Accuracy: 79.21%
# Epoch 47, Training Loss: 0.3330, Training Accuracy: 86.01%, Validatoin Loss: 0.4620, Validatoin Accuracy: 79.41%
# Epoch 48, Training Loss: 0.3188, Training Accuracy: 86.11%, Validatoin Loss: 0.4190, Validatoin Accuracy: 82.38%
# Epoch 49, Training Loss: 0.2629, Training Accuracy: 89.09%, Validatoin Loss: 0.4237, Validatoin Accuracy: 82.18%
# Epoch 50, Training Loss: 0.2671, Training Accuracy: 88.69%, Validatoin Loss: 0.3847, Validatoin Accuracy: 84.16%
# Epoch 51, Training Loss: 0.2659, Training Accuracy: 89.34%, Validatoin Loss: 0.4324, Validatoin Accuracy: 79.80%
# Epoch 52, Training Loss: 0.2444, Training Accuracy: 89.73%, Validatoin Loss: 0.4470, Validatoin Accuracy: 81.78%
# Epoch 53, Training Loss: 0.2138, Training Accuracy: 91.07%, Validatoin Loss: 0.4032, Validatoin Accuracy: 84.36%
# Epoch 54, Training Loss: 0.2112, Training Accuracy: 91.52%, Validatoin Loss: 0.7041, Validatoin Accuracy: 77.03%
# Epoch 55, Training Loss: 0.2189, Training Accuracy: 90.92%, Validatoin Loss: 0.4187, Validatoin Accuracy: 85.54%
# Epoch 56, Training Loss: 0.2024, Training Accuracy: 91.67%, Validatoin Loss: 0.4140, Validatoin Accuracy: 83.37%
# Epoch 57, Training Loss: 0.1668, Training Accuracy: 93.55%, Validatoin Loss: 0.4837, Validatoin Accuracy: 81.58%
# Epoch 58, Training Loss: 0.1824, Training Accuracy: 92.76%, Validatoin Loss: 0.5572, Validatoin Accuracy: 80.99%
# Epoch 59, Training Loss: 0.1276, Training Accuracy: 94.99%, Validatoin Loss: 0.4832, Validatoin Accuracy: 83.17%
# Epoch 60, Training Loss: 0.1289, Training Accuracy: 95.59%, Validatoin Loss: 0.4584, Validatoin Accuracy: 83.37%
# Epoch 61, Training Loss: 0.1351, Training Accuracy: 94.94%, Validatoin Loss: 0.4719, Validatoin Accuracy: 81.58%
# Epoch 62, Training Loss: 0.1109, Training Accuracy: 95.78%, Validatoin Loss: 0.4036, Validatoin Accuracy: 86.53%
# Epoch 63, Training Loss: 0.1468, Training Accuracy: 94.99%, Validatoin Loss: 0.9536, Validatoin Accuracy: 76.63%
# Epoch 64, Training Loss: 0.1141, Training Accuracy: 95.59%, Validatoin Loss: 0.4007, Validatoin Accuracy: 84.75%
# Epoch 65, Training Loss: 0.0928, Training Accuracy: 96.23%, Validatoin Loss: 0.5346, Validatoin Accuracy: 82.97%
# Epoch 66, Training Loss: 0.0966, Training Accuracy: 96.33%, Validatoin Loss: 0.5007, Validatoin Accuracy: 85.54%
# Epoch 67, Training Loss: 0.1104, Training Accuracy: 95.59%, Validatoin Loss: 0.5055, Validatoin Accuracy: 83.96%
# Epoch 68, Training Loss: 0.0956, Training Accuracy: 96.53%, Validatoin Loss: 0.4155, Validatoin Accuracy: 85.35%
# Epoch 69, Training Loss: 0.0825, Training Accuracy: 97.22%, Validatoin Loss: 0.8537, Validatoin Accuracy: 80.79%
# Epoch 70, Training Loss: 0.0762, Training Accuracy: 97.32%, Validatoin Loss: 0.6081, Validatoin Accuracy: 83.76%
# Epoch 71, Training Loss: 0.0723, Training Accuracy: 97.57%, Validatoin Loss: 0.5588, Validatoin Accuracy: 84.16%
# Epoch 72, Training Loss: 0.0629, Training Accuracy: 97.47%, Validatoin Loss: 0.6191, Validatoin Accuracy: 83.76%
# Epoch 73, Training Loss: 0.0792, Training Accuracy: 97.17%, Validatoin Loss: 0.7799, Validatoin Accuracy: 82.38%
# Epoch 74, Training Loss: 0.0596, Training Accuracy: 97.77%, Validatoin Loss: 0.5883, Validatoin Accuracy: 83.17%
# Epoch 75, Training Loss: 0.1009, Training Accuracy: 96.53%, Validatoin Loss: 0.5955, Validatoin Accuracy: 83.96%
# Epoch 76, Training Loss: 0.0642, Training Accuracy: 97.82%, Validatoin Loss: 0.4482, Validatoin Accuracy: 86.93%
# Epoch 77, Training Loss: 0.0616, Training Accuracy: 97.92%, Validatoin Loss: 0.4684, Validatoin Accuracy: 86.53%
# Epoch 78, Training Loss: 0.0903, Training Accuracy: 96.58%, Validatoin Loss: 0.6260, Validatoin Accuracy: 82.18%
# Epoch 79, Training Loss: 0.0520, Training Accuracy: 98.41%, Validatoin Loss: 0.4672, Validatoin Accuracy: 85.15%
# Epoch 80, Training Loss: 0.0572, Training Accuracy: 98.16%, Validatoin Loss: 0.4514, Validatoin Accuracy: 86.53%
# Epoch 81, Training Loss: 0.0729, Training Accuracy: 97.22%, Validatoin Loss: 0.4841, Validatoin Accuracy: 84.16%
# Epoch 82, Training Loss: 0.0502, Training Accuracy: 98.16%, Validatoin Loss: 0.5139, Validatoin Accuracy: 85.15%
# Epoch 83, Training Loss: 0.0477, Training Accuracy: 98.41%, Validatoin Loss: 0.4901, Validatoin Accuracy: 86.14%
# Epoch 84, Training Loss: 0.0597, Training Accuracy: 97.77%, Validatoin Loss: 0.6447, Validatoin Accuracy: 84.36%
# Epoch 85, Training Loss: 0.0361, Training Accuracy: 98.91%, Validatoin Loss: 0.5150, Validatoin Accuracy: 85.94%
# Epoch 86, Training Loss: 0.0528, Training Accuracy: 98.07%, Validatoin Loss: 0.5268, Validatoin Accuracy: 86.53%
# Epoch 87, Training Loss: 0.0317, Training Accuracy: 99.11%, Validatoin Loss: 0.9198, Validatoin Accuracy: 77.23%
# Epoch 88, Training Loss: 0.0783, Training Accuracy: 96.83%, Validatoin Loss: 0.5210, Validatoin Accuracy: 85.94%
# Epoch 89, Training Loss: 0.0522, Training Accuracy: 98.21%, Validatoin Loss: 0.6636, Validatoin Accuracy: 84.75%
# Epoch 90, Training Loss: 0.0515, Training Accuracy: 98.12%, Validatoin Loss: 0.4804, Validatoin Accuracy: 86.73%
# Epoch 91, Training Loss: 0.0263, Training Accuracy: 99.21%, Validatoin Loss: 0.4999, Validatoin Accuracy: 87.13%
# Epoch 92, Training Loss: 0.0340, Training Accuracy: 99.01%, Validatoin Loss: 0.4884, Validatoin Accuracy: 86.93%
# Epoch 93, Training Loss: 0.0288, Training Accuracy: 98.96%, Validatoin Loss: 0.5764, Validatoin Accuracy: 83.96%
# Epoch 94, Training Loss: 0.0221, Training Accuracy: 99.26%, Validatoin Loss: 0.5339, Validatoin Accuracy: 87.52%
# Epoch 95, Training Loss: 0.0340, Training Accuracy: 98.71%, Validatoin Loss: 0.7655, Validatoin Accuracy: 84.75%
# Epoch 96, Training Loss: 0.0412, Training Accuracy: 98.46%, Validatoin Loss: 0.5403, Validatoin Accuracy: 85.94%
# Epoch 97, Training Loss: 0.0330, Training Accuracy: 98.96%, Validatoin Loss: 0.5653, Validatoin Accuracy: 87.13%
# Epoch 98, Training Loss: 0.0322, Training Accuracy: 98.86%, Validatoin Loss: 0.5205, Validatoin Accuracy: 86.73%
# Epoch 99, Training Loss: 0.0346, Training Accuracy: 99.01%, Validatoin Loss: 0.5324, Validatoin Accuracy: 87.13%
# Epoch 100, Training Loss: 0.0457, Training Accuracy: 98.51%, Validatoin Loss: 0.6878, Validatoin Accuracy: 83.76%
# Epoch 101, Training Loss: 0.0622, Training Accuracy: 98.02%, Validatoin Loss: 0.7409, Validatoin Accuracy: 81.58%
# Epoch 102, Training Loss: 0.0944, Training Accuracy: 96.92%, Validatoin Loss: 0.4801, Validatoin Accuracy: 87.52%
# Epoch 103, Training Loss: 0.0316, Training Accuracy: 99.01%, Validatoin Loss: 0.5084, Validatoin Accuracy: 86.73%
# Epoch 104, Training Loss: 0.0437, Training Accuracy: 98.41%, Validatoin Loss: 0.4229, Validatoin Accuracy: 88.91%
# Epoch 105, Training Loss: 0.0317, Training Accuracy: 99.11%, Validatoin Loss: 0.5040, Validatoin Accuracy: 86.93%
# Epoch 106, Training Loss: 0.0147, Training Accuracy: 99.60%, Validatoin Loss: 0.5213, Validatoin Accuracy: 86.93%
# Epoch 107, Training Loss: 0.0172, Training Accuracy: 99.55%, Validatoin Loss: 0.4966, Validatoin Accuracy: 87.92%
# Epoch 108, Training Loss: 0.0395, Training Accuracy: 98.86%, Validatoin Loss: 0.4731, Validatoin Accuracy: 88.71%
# Epoch 109, Training Loss: 0.0358, Training Accuracy: 98.76%, Validatoin Loss: 0.7333, Validatoin Accuracy: 83.76%
# Epoch 110, Training Loss: 0.0259, Training Accuracy: 99.01%, Validatoin Loss: 0.5080, Validatoin Accuracy: 86.34%
# Epoch 111, Training Loss: 0.0155, Training Accuracy: 99.45%, Validatoin Loss: 0.6196, Validatoin Accuracy: 85.35%
# Epoch 112, Training Loss: 0.0197, Training Accuracy: 99.21%, Validatoin Loss: 0.6204, Validatoin Accuracy: 85.94%
# Epoch 113, Training Loss: 0.0172, Training Accuracy: 99.50%, Validatoin Loss: 0.5033, Validatoin Accuracy: 86.73%
# Epoch 114, Training Loss: 0.0223, Training Accuracy: 99.11%, Validatoin Loss: 0.5041, Validatoin Accuracy: 87.92%
# Epoch 115, Training Loss: 0.0199, Training Accuracy: 99.31%, Validatoin Loss: 0.4651, Validatoin Accuracy: 87.92%
# Epoch 116, Training Loss: 0.0181, Training Accuracy: 99.26%, Validatoin Loss: 0.4968, Validatoin Accuracy: 87.52%
# Epoch 117, Training Loss: 0.0107, Training Accuracy: 99.50%, Validatoin Loss: 0.6012, Validatoin Accuracy: 86.93%
# Epoch 118, Training Loss: 0.0160, Training Accuracy: 99.45%, Validatoin Loss: 0.6088, Validatoin Accuracy: 87.33%
# Epoch 119, Training Loss: 0.0165, Training Accuracy: 99.55%, Validatoin Loss: 0.4915, Validatoin Accuracy: 87.52%
# Epoch 120, Training Loss: 0.0122, Training Accuracy: 99.55%, Validatoin Loss: 0.5899, Validatoin Accuracy: 87.33%
# Epoch 121, Training Loss: 0.0123, Training Accuracy: 99.50%, Validatoin Loss: 0.6525, Validatoin Accuracy: 85.94%
# Epoch 122, Training Loss: 0.0168, Training Accuracy: 99.45%, Validatoin Loss: 0.6331, Validatoin Accuracy: 86.93%
# Epoch 123, Training Loss: 0.0108, Training Accuracy: 99.80%, Validatoin Loss: 0.5611, Validatoin Accuracy: 87.72%
# Epoch 124, Training Loss: 0.0136, Training Accuracy: 99.80%, Validatoin Loss: 0.6887, Validatoin Accuracy: 86.34%
# Epoch 125, Training Loss: 0.0195, Training Accuracy: 99.36%, Validatoin Loss: 0.5273, Validatoin Accuracy: 86.93%
# Epoch 126, Training Loss: 0.0134, Training Accuracy: 99.50%, Validatoin Loss: 0.5334, Validatoin Accuracy: 87.52%
# Epoch 127, Training Loss: 0.0148, Training Accuracy: 99.50%, Validatoin Loss: 0.5965, Validatoin Accuracy: 85.35%
# Epoch 128, Training Loss: 0.0237, Training Accuracy: 99.16%, Validatoin Loss: 0.6049, Validatoin Accuracy: 86.14%
# Epoch 129, Training Loss: 0.0220, Training Accuracy: 99.21%, Validatoin Loss: 0.6732, Validatoin Accuracy: 86.14%
# Epoch 130, Training Loss: 0.0160, Training Accuracy: 99.36%, Validatoin Loss: 0.7407, Validatoin Accuracy: 84.75%
# Epoch 131, Training Loss: 0.0228, Training Accuracy: 99.16%, Validatoin Loss: 0.5333, Validatoin Accuracy: 88.12%
# Epoch 132, Training Loss: 0.0164, Training Accuracy: 99.40%, Validatoin Loss: 0.5331, Validatoin Accuracy: 88.12%
# Epoch 133, Training Loss: 0.0119, Training Accuracy: 99.65%, Validatoin Loss: 0.4727, Validatoin Accuracy: 89.11%
# Epoch 134, Training Loss: 0.0166, Training Accuracy: 99.55%, Validatoin Loss: 0.4791, Validatoin Accuracy: 89.11%
# Epoch 135, Training Loss: 0.0240, Training Accuracy: 99.06%, Validatoin Loss: 0.9514, Validatoin Accuracy: 83.76%
# Epoch 136, Training Loss: 0.0211, Training Accuracy: 99.21%, Validatoin Loss: 0.5411, Validatoin Accuracy: 87.72%
# Epoch 137, Training Loss: 0.0284, Training Accuracy: 99.01%, Validatoin Loss: 0.4848, Validatoin Accuracy: 87.13%
# Epoch 138, Training Loss: 0.0086, Training Accuracy: 99.65%, Validatoin Loss: 0.4851, Validatoin Accuracy: 88.71%
# Epoch 139, Training Loss: 0.0222, Training Accuracy: 99.16%, Validatoin Loss: 0.8065, Validatoin Accuracy: 82.77%
# Epoch 140, Training Loss: 0.0139, Training Accuracy: 99.55%, Validatoin Loss: 0.5604, Validatoin Accuracy: 87.72%
# Epoch 141, Training Loss: 0.0097, Training Accuracy: 99.75%, Validatoin Loss: 0.6229, Validatoin Accuracy: 86.73%
# Epoch 142, Training Loss: 0.0073, Training Accuracy: 99.80%, Validatoin Loss: 0.4935, Validatoin Accuracy: 88.12%
# Epoch 143, Training Loss: 0.0152, Training Accuracy: 99.50%, Validatoin Loss: 0.5179, Validatoin Accuracy: 88.71%
# Epoch 144, Training Loss: 0.0112, Training Accuracy: 99.75%, Validatoin Loss: 0.5649, Validatoin Accuracy: 87.52%
# Epoch 145, Training Loss: 0.0101, Training Accuracy: 99.70%, Validatoin Loss: 0.5920, Validatoin Accuracy: 87.72%
# Epoch 146, Training Loss: 0.0114, Training Accuracy: 99.65%, Validatoin Loss: 0.8639, Validatoin Accuracy: 84.95%
# Epoch 147, Training Loss: 0.0156, Training Accuracy: 99.50%, Validatoin Loss: 0.6286, Validatoin Accuracy: 87.33%
# Epoch 148, Training Loss: 0.0084, Training Accuracy: 99.65%, Validatoin Loss: 0.6011, Validatoin Accuracy: 87.52%
# Epoch 149, Training Loss: 0.0080, Training Accuracy: 99.80%, Validatoin Loss: 0.6324, Validatoin Accuracy: 87.52%
# Epoch 150, Training Loss: 0.0123, Training Accuracy: 99.65%, Validatoin Loss: 0.6117, Validatoin Accuracy: 87.13%

# %%
model_R.eval()
all_labels = [] 
all_scores = []  

with torch.no_grad():
    for i, data in enumerate(val_loader, 0):  # val_loader or train_loader
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model_R(inputs)

        all_labels.extend(labels.cpu().numpy())  # real label
        all_scores.extend(outputs[:, 1].cpu().numpy())  # model predict score

# Calculate AUC
fpr, tpr, thresholds = roc_curve(all_labels, all_scores)
auroc = auc(fpr, tpr)

print(f"AUROC: {auroc:.4f}")

# draw ROC
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUROC = {auroc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# AUROC: 0.9479

# %%
torch.save(model_R,'model_BMI.pt')
torch.save(model_R.state_dict(),'model_BMI(weight).pt')
