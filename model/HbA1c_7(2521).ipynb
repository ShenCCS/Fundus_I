# %%
import torch
import models_vit
import torch.nn as nn
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, auc

from pathlib import  Path
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from util.pos_embed import interpolate_pos_embed
from timm.models.layers import trunc_normal_
from torch.nn import Linear,ReLU,CrossEntropyLoss

# %%
# call the model
model_R = models_vit.__dict__['vit_large_patch16'](
    num_classes=2,
    drop_path_rate=0.2,
    global_pool=True,
)

# load RETFound weights
checkpoint = torch.load('RETFound_cfp_weights.pth', map_location='cpu')
checkpoint_model = checkpoint['model']
state_dict = model_R.state_dict()

for k in ['head.weight', 'head.bias']:
    if k in checkpoint_model and checkpoint_model[k].shape != state_dict[k].shape:
        print(f"Removing key {k} from pretrained checkpoint")
        del checkpoint_model[k]

# interpolate position embedding
interpolate_pos_embed(model_R, checkpoint_model)

# load pre-trained model
msg = model_R.load_state_dict(checkpoint_model, strict=False)

assert set(msg.missing_keys) == {'head.weight', 'head.bias', 'fc_norm.weight', 'fc_norm.bias'}

# manually initialize fc layer
trunc_normal_(model_R.head.weight, std=2e-5)

#print("Model = %s" % str(model_R))
# Out:
# Parameter containing:
# tensor([[-2.1187e-05,  1.3602e-05, -1.2902e-06,  ...,  1.3537e-05,
#           2.4994e-05,  1.4303e-06],
#         [ 1.3753e-05, -9.9898e-06, -1.9520e-05,  ..., -1.2518e-05,
#           3.3791e-05,  2.1685e-07]], requires_grad=True)

# %%
data_transform = transforms.Compose([transforms.Resize((224, 224)),transforms.ToTensor()])
# train_data = datasets.ImageFolder('/home/john/network/RETFound/RETFound_MAE-main/data/Gender/', transform=data_transform)
train_data = datasets.ImageFolder('/home/cluster/Fundus/RETFound_MAE-main/data/HbA1c/7.0/', transform=data_transform)

total_data = len(train_data)
split = int(0.8 * total_data)

# %%
training_data, validation_data = torch.utils.data.random_split(train_data,[split,total_data - split])

# %%
total_data,split
# Out:
# (2465, 1972)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_R.to(device)

train_loader = torch.utils.data.DataLoader(training_data, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(validation_data, batch_size=32, shuffle=True)


criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)
optimizer = optim.SGD(model_R.parameters(), lr=0.001, momentum=0.9)


num_epochs = 150
training_loss = []  
validation_loss = []
train_acc = []
validatoin_acc = []

#Training

for epoch in range(num_epochs):
    model_R.train()
    running_train_loss = 0.0
    train_correct = 0
    train_total = 0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model_R(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_train_loss / len(train_loader)
    train_accuary = train_correct / train_total
    training_loss.append(train_loss)
    train_acc.append(train_accuary)


#Validation

    model_R.eval()
    running_val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for i,data in enumerate(val_loader,0):
            inputs,labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_R(inputs)
            val_loss = criterion(outputs,labels)
            running_val_loss += val_loss.item()

            _,predicted = torch.max(outputs,1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()


    val_loss = running_val_loss / len(val_loader)
    val_accuracy = val_correct / val_total
    validation_loss.append(val_loss)
    validatoin_acc.append(val_accuracy)
    

    print(f"Epoch {epoch+1}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuary*100:.2f}%, Validatoin Loss: {val_loss:.4f}, Validatoin Accuracy: {val_accuracy*100:.2f}%")
    if (epoch + 1) %  10 == 0:
        torch.save(model_R.state_dict(),f"HbA1C7.0_model_checkpoint_epoch_{epoch + 1}.pth")

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_loss,label = 'Training')
plt.plot(range(1, num_epochs + 1), validation_loss,label = 'Validation')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_acc,color='g',label = 'Training')
plt.plot(range(1, num_epochs + 1), validatoin_acc,color='r',label = 'Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 0.7077, Training Accuracy: 52.13%, Validatoin Loss: 0.7155, Validatoin Accuracy: 46.65%
# Epoch 2, Training Loss: 0.6933, Training Accuracy: 54.67%, Validatoin Loss: 0.6737, Validatoin Accuracy: 58.01%
# Epoch 3, Training Loss: 0.7213, Training Accuracy: 53.14%, Validatoin Loss: 0.6824, Validatoin Accuracy: 57.20%
# Epoch 4, Training Loss: 0.7026, Training Accuracy: 53.80%, Validatoin Loss: 0.7983, Validatoin Accuracy: 54.16%
# Epoch 5, Training Loss: 0.7261, Training Accuracy: 55.12%, Validatoin Loss: 0.6750, Validatoin Accuracy: 57.81%
# Epoch 6, Training Loss: 0.7146, Training Accuracy: 54.51%, Validatoin Loss: 0.7592, Validatoin Accuracy: 54.16%
# Epoch 7, Training Loss: 0.6873, Training Accuracy: 57.10%, Validatoin Loss: 0.6674, Validatoin Accuracy: 59.03%
# Epoch 8, Training Loss: 0.7189, Training Accuracy: 55.32%, Validatoin Loss: 0.6871, Validatoin Accuracy: 55.78%
# Epoch 9, Training Loss: 0.7337, Training Accuracy: 54.06%, Validatoin Loss: 0.7456, Validatoin Accuracy: 50.30%
# Epoch 10, Training Loss: 0.7059, Training Accuracy: 57.71%, Validatoin Loss: 0.6624, Validatoin Accuracy: 61.26%
# Epoch 11, Training Loss: 0.6923, Training Accuracy: 57.56%, Validatoin Loss: 0.6857, Validatoin Accuracy: 56.39%
# Epoch 12, Training Loss: 0.6977, Training Accuracy: 57.45%, Validatoin Loss: 0.6643, Validatoin Accuracy: 60.45%
# Epoch 13, Training Loss: 0.6812, Training Accuracy: 57.45%, Validatoin Loss: 0.6828, Validatoin Accuracy: 57.20%
# Epoch 14, Training Loss: 0.6634, Training Accuracy: 59.89%, Validatoin Loss: 0.6839, Validatoin Accuracy: 57.81%
# Epoch 15, Training Loss: 0.6662, Training Accuracy: 58.47%, Validatoin Loss: 0.7197, Validatoin Accuracy: 56.59%
# Epoch 16, Training Loss: 0.6585, Training Accuracy: 59.43%, Validatoin Loss: 0.6523, Validatoin Accuracy: 61.05%
# Epoch 132, Training Loss: 0.0267, Training Accuracy: 99.09%, Validatoin Loss: 0.7071, Validatoin Accuracy: 83.16%
# Epoch 133, Training Loss: 0.0216, Training Accuracy: 99.19%, Validatoin Loss: 0.7593, Validatoin Accuracy: 82.15%
# Epoch 134, Training Loss: 0.0141, Training Accuracy: 99.39%, Validatoin Loss: 0.9517, Validatoin Accuracy: 81.95%
# Epoch 135, Training Loss: 0.0233, Training Accuracy: 99.04%, Validatoin Loss: 0.7670, Validatoin Accuracy: 83.37%
# Epoch 136, Training Loss: 0.0161, Training Accuracy: 99.39%, Validatoin Loss: 0.7552, Validatoin Accuracy: 84.38%
# Epoch 137, Training Loss: 0.0220, Training Accuracy: 99.39%, Validatoin Loss: 0.9311, Validatoin Accuracy: 81.74%
# Epoch 138, Training Loss: 0.0249, Training Accuracy: 99.09%, Validatoin Loss: 0.9018, Validatoin Accuracy: 82.56%
# Epoch 139, Training Loss: 0.0232, Training Accuracy: 99.24%, Validatoin Loss: 1.2647, Validatoin Accuracy: 79.51%
# Epoch 140, Training Loss: 0.0222, Training Accuracy: 99.29%, Validatoin Loss: 1.0439, Validatoin Accuracy: 80.73%
# Epoch 141, Training Loss: 0.0322, Training Accuracy: 98.68%, Validatoin Loss: 1.0273, Validatoin Accuracy: 80.53%
# Epoch 142, Training Loss: 0.0145, Training Accuracy: 99.49%, Validatoin Loss: 0.9928, Validatoin Accuracy: 80.93%
# Epoch 143, Training Loss: 0.0209, Training Accuracy: 99.34%, Validatoin Loss: 0.7710, Validatoin Accuracy: 82.76%
# Epoch 144, Training Loss: 0.0353, Training Accuracy: 98.73%, Validatoin Loss: 0.6937, Validatoin Accuracy: 84.38%
# Epoch 145, Training Loss: 0.0310, Training Accuracy: 98.73%, Validatoin Loss: 0.7498, Validatoin Accuracy: 84.58%
# Epoch 146, Training Loss: 0.0291, Training Accuracy: 98.88%, Validatoin Loss: 1.1015, Validatoin Accuracy: 79.51%
# Epoch 147, Training Loss: 0.0422, Training Accuracy: 98.68%, Validatoin Loss: 0.7539, Validatoin Accuracy: 83.77%
# Epoch 148, Training Loss: 0.0207, Training Accuracy: 99.34%, Validatoin Loss: 0.7005, Validatoin Accuracy: 84.79%
# Epoch 149, Training Loss: 0.0265, Training Accuracy: 99.04%, Validatoin Loss: 0.7263, Validatoin Accuracy: 84.58%
# Epoch 150, Training Loss: 0.0163, Training Accuracy: 99.54%, Validatoin Loss: 0.7058, Validatoin Accuracy: 83.98%

# %%
model_R.eval()
all_labels = [] 
all_scores = []  

with torch.no_grad():
    for i, data in enumerate(val_loader, 0):  # val_loader or train_loader
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model_R(inputs)

        all_labels.extend(labels.cpu().numpy())  # real label
        all_scores.extend(outputs[:, 1].cpu().numpy())  # model predict score

# Calculate AUC
fpr, tpr, thresholds = roc_curve(all_labels, all_scores)
auroc = auc(fpr, tpr)

print(f"AUROC: {auroc:.4f}")

# draw ROC
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUROC = {auroc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# AUROC: 0.9227
