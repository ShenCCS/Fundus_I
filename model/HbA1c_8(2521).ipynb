# %%
import torch
import models_vit
import torch.nn as nn
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, auc

from pathlib import  Path
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from util.pos_embed import interpolate_pos_embed
from timm.models.layers import trunc_normal_
from torch.nn import Linear,ReLU,CrossEntropyLoss

# %%
# call the model
model_R = models_vit.__dict__['vit_large_patch16'](
    num_classes=2,
    drop_path_rate=0.2,
    global_pool=True,
)

# load RETFound weights
checkpoint = torch.load('RETFound_cfp_weights.pth', map_location='cpu')
checkpoint_model = checkpoint['model']
state_dict = model_R.state_dict()

for k in ['head.weight', 'head.bias']:
    if k in checkpoint_model and checkpoint_model[k].shape != state_dict[k].shape:
        print(f"Removing key {k} from pretrained checkpoint")
        del checkpoint_model[k]

# interpolate position embedding
interpolate_pos_embed(model_R, checkpoint_model)

# load pre-trained model
msg = model_R.load_state_dict(checkpoint_model, strict=False)

assert set(msg.missing_keys) == {'head.weight', 'head.bias', 'fc_norm.weight', 'fc_norm.bias'}

# manually initialize fc layer
trunc_normal_(model_R.head.weight, std=2e-5)

#print("Model = %s" % str(model_R))
# Out:
# Parameter containing:
# tensor([[-8.5926e-06, -1.7389e-05, -5.3031e-05,  ..., -3.8000e-06,
#           1.8522e-05,  8.0825e-06],
#         [-5.2304e-06,  4.1463e-06, -7.4435e-06,  ..., -1.0390e-05,
#          -4.2696e-05, -2.1907e-05]], requires_grad=True)

# %%
data_transform = transforms.Compose([transforms.Resize((224, 224)),transforms.ToTensor()])
# train_data = datasets.ImageFolder('/home/john/network/RETFound/RETFound_MAE-main/data/HbA1c/7.0/', transform=data_transform)
train_data = datasets.ImageFolder('/home/cluster/Fundus/RETFound_MAE-main/data/HbA1c/8.0/', transform=data_transform)

total_data = len(train_data)
split = int(0.8 * total_data)

# %%
total_data,split
# Out:
# (2465, 1972)

# %%
training_data, validation_data = torch.utils.data.random_split(train_data,[split,total_data - split])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_R.to(device)

train_loader = torch.utils.data.DataLoader(training_data, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(validation_data, batch_size=32, shuffle=True)


criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)
optimizer = optim.SGD(model_R.parameters(), lr=0.001, momentum=0.9)


num_epochs = 150
training_loss = []  
validation_loss = []
train_acc = []
validatoin_acc = []

#Training

for epoch in range(num_epochs):
    model_R.train()
    running_train_loss = 0.0
    train_correct = 0
    train_total = 0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model_R(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_train_loss / len(train_loader)
    train_accuary = train_correct / train_total
    training_loss.append(train_loss)
    train_acc.append(train_accuary)


#Validation

    model_R.eval()
    running_val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for i,data in enumerate(val_loader,0):
            inputs,labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_R(inputs)
            val_loss = criterion(outputs,labels)
            running_val_loss += val_loss.item()

            _,predicted = torch.max(outputs,1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()


    val_loss = running_val_loss / len(val_loader)
    val_accuracy = val_correct / val_total
    validation_loss.append(val_loss)
    validatoin_acc.append(val_accuracy)
    

    print(f"Epoch {epoch+1}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuary*100:.2f}%, Validatoin Loss: {val_loss:.4f}, Validatoin Accuracy: {val_accuracy*100:.2f}%")
    if (epoch + 1) %  10 == 0:
        torch.save(model_R.state_dict(),f"HbA1C8.0_model_checkpoint_epoch_{epoch + 1}.pth")

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_loss,label = 'Training')
plt.plot(range(1, num_epochs + 1), validation_loss,label = 'Validation')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_acc,color='g',label = 'Training')
plt.plot(range(1, num_epochs + 1), validatoin_acc,color='r',label = 'Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 0.5267, Training Accuracy: 79.61%, Validatoin Loss: 0.5704, Validatoin Accuracy: 76.06%
# Epoch 2, Training Loss: 0.5156, Training Accuracy: 79.46%, Validatoin Loss: 0.6995, Validatoin Accuracy: 76.06%
# Epoch 3, Training Loss: 0.5092, Training Accuracy: 79.72%, Validatoin Loss: 0.5685, Validatoin Accuracy: 76.06%
# Epoch 4, Training Loss: 0.5101, Training Accuracy: 79.97%, Validatoin Loss: 0.5354, Validatoin Accuracy: 76.06%
# Epoch 5, Training Loss: 0.5241, Training Accuracy: 79.77%, Validatoin Loss: 0.5776, Validatoin Accuracy: 76.06%
# Epoch 6, Training Loss: 0.5266, Training Accuracy: 79.31%, Validatoin Loss: 0.5754, Validatoin Accuracy: 76.06%
# Epoch 7, Training Loss: 0.5016, Training Accuracy: 80.02%, Validatoin Loss: 0.5479, Validatoin Accuracy: 76.06%
# Epoch 8, Training Loss: 0.5011, Training Accuracy: 79.77%, Validatoin Loss: 0.5403, Validatoin Accuracy: 76.06%
# Epoch 9, Training Loss: 0.4992, Training Accuracy: 80.07%, Validatoin Loss: 0.5307, Validatoin Accuracy: 76.88%
# Epoch 10, Training Loss: 0.5121, Training Accuracy: 79.87%, Validatoin Loss: 0.5207, Validatoin Accuracy: 76.67%
# Epoch 11, Training Loss: 0.5038, Training Accuracy: 79.51%, Validatoin Loss: 0.5326, Validatoin Accuracy: 76.67%
# Epoch 12, Training Loss: 0.4994, Training Accuracy: 80.22%, Validatoin Loss: 0.5946, Validatoin Accuracy: 72.82%
# Epoch 13, Training Loss: 0.5051, Training Accuracy: 79.06%, Validatoin Loss: 0.5993, Validatoin Accuracy: 76.06%
# Epoch 14, Training Loss: 0.5000, Training Accuracy: 80.07%, Validatoin Loss: 0.5210, Validatoin Accuracy: 77.08%
# Epoch 15, Training Loss: 0.4813, Training Accuracy: 79.92%, Validatoin Loss: 0.5507, Validatoin Accuracy: 76.06%
# Epoch 16, Training Loss: 0.4710, Training Accuracy: 80.53%, Validatoin Loss: 0.5505, Validatoin Accuracy: 76.06%
# Epoch 132, Training Loss: 0.0111, Training Accuracy: 99.49%, Validatoin Loss: 1.1552, Validatoin Accuracy: 84.18%
# Epoch 133, Training Loss: 0.0172, Training Accuracy: 99.24%, Validatoin Loss: 1.1550, Validatoin Accuracy: 84.38%
# Epoch 134, Training Loss: 0.0071, Training Accuracy: 99.80%, Validatoin Loss: 0.9628, Validatoin Accuracy: 85.80%
# Epoch 135, Training Loss: 0.0092, Training Accuracy: 99.70%, Validatoin Loss: 1.0434, Validatoin Accuracy: 84.99%
# Epoch 136, Training Loss: 0.0163, Training Accuracy: 99.34%, Validatoin Loss: 0.9089, Validatoin Accuracy: 86.61%
# Epoch 137, Training Loss: 0.0229, Training Accuracy: 99.39%, Validatoin Loss: 0.8533, Validatoin Accuracy: 86.82%
# Epoch 138, Training Loss: 0.0071, Training Accuracy: 99.75%, Validatoin Loss: 0.8887, Validatoin Accuracy: 85.80%
# Epoch 139, Training Loss: 0.0126, Training Accuracy: 99.49%, Validatoin Loss: 0.7540, Validatoin Accuracy: 86.00%
# Epoch 140, Training Loss: 0.0045, Training Accuracy: 99.85%, Validatoin Loss: 0.8133, Validatoin Accuracy: 85.80%
# Epoch 141, Training Loss: 0.0118, Training Accuracy: 99.75%, Validatoin Loss: 1.1006, Validatoin Accuracy: 86.00%
# Epoch 142, Training Loss: 0.0081, Training Accuracy: 99.80%, Validatoin Loss: 0.9711, Validatoin Accuracy: 86.82%
# Epoch 143, Training Loss: 0.0119, Training Accuracy: 99.59%, Validatoin Loss: 1.2461, Validatoin Accuracy: 84.79%
# Epoch 144, Training Loss: 0.0080, Training Accuracy: 99.70%, Validatoin Loss: 0.9294, Validatoin Accuracy: 87.83%
# Epoch 145, Training Loss: 0.0099, Training Accuracy: 99.59%, Validatoin Loss: 0.7558, Validatoin Accuracy: 86.00%
# Epoch 146, Training Loss: 0.0138, Training Accuracy: 99.59%, Validatoin Loss: 0.8887, Validatoin Accuracy: 87.83%
# Epoch 147, Training Loss: 0.0074, Training Accuracy: 99.80%, Validatoin Loss: 0.8036, Validatoin Accuracy: 86.61%
# Epoch 148, Training Loss: 0.0125, Training Accuracy: 99.54%, Validatoin Loss: 1.0424, Validatoin Accuracy: 85.60%
# Epoch 149, Training Loss: 0.0116, Training Accuracy: 99.49%, Validatoin Loss: 1.2110, Validatoin Accuracy: 84.79%
# Epoch 150, Training Loss: 0.0094, Training Accuracy: 99.59%, Validatoin Loss: 0.8353, Validatoin Accuracy: 87.22%

# %%
model_R.eval()
all_labels = [] 
all_scores = []  

with torch.no_grad():
    for i, data in enumerate(val_loader, 0):  # val_loader or train_loader
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model_R(inputs)

        all_labels.extend(labels.cpu().numpy())  # real label
        all_scores.extend(outputs[:, 1].cpu().numpy())  # model predict score

# Calculate AUC
fpr, tpr, thresholds = roc_curve(all_labels, all_scores)
auroc = auc(fpr, tpr)

print(f"AUROC: {auroc:.4f}")

# draw ROC
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUROC = {auroc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# AUROC: 0.9118
