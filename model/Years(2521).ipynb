# %%
import torch
import models_vit
import torch.nn as nn
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, auc

from pathlib import  Path
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from util.pos_embed import interpolate_pos_embed
from timm.models.layers import trunc_normal_
from torch.nn import Linear,ReLU,CrossEntropyLoss

# %%
# call the model
model_R = models_vit.__dict__['vit_large_patch16'](
    num_classes=2,
    drop_path_rate=0.2,
    global_pool=True,
)

# load RETFound weights
checkpoint = torch.load('RETFound_cfp_weights.pth', map_location='cpu')
checkpoint_model = checkpoint['model']
state_dict = model_R.state_dict()

for k in ['head.weight', 'head.bias']:
    if k in checkpoint_model and checkpoint_model[k].shape != state_dict[k].shape:
        print(f"Removing key {k} from pretrained checkpoint")
        del checkpoint_model[k]

# interpolate position embedding
interpolate_pos_embed(model_R, checkpoint_model)

# load pre-trained model
msg = model_R.load_state_dict(checkpoint_model, strict=False)

assert set(msg.missing_keys) == {'head.weight', 'head.bias', 'fc_norm.weight', 'fc_norm.bias'}

# manually initialize fc layer
trunc_normal_(model_R.head.weight, std=2e-5)

#print("Model = %s" % str(model_R))
# Out:
# Parameter containing:
# tensor([[-1.7604e-05, -9.2063e-06,  3.7540e-05,  ...,  2.1461e-05,
#           8.6540e-06,  3.1494e-05],
#         [ 2.4346e-06, -1.1896e-05,  3.6434e-06,  ..., -2.8053e-06,
#          -2.7563e-05,  3.5308e-05]], requires_grad=True)

# %%
data_transform = transforms.Compose([transforms.Resize((224, 224)),transforms.ToTensor()])
# train_data = datasets.ImageFolder('/home/john/network/RETFound/RETFound_MAE-main/data/HbA1c/7.0/', transform=data_transform)
train_data = datasets.ImageFolder('/home/cluster/Fundus/RETFound_MAE-main/data/HowLong/', transform=data_transform)

total_data = len(train_data)
split = int(0.8 * total_data)

# %%
total_data,split
# Out:
# (2490, 1992)

# %%
training_data, validation_data = torch.utils.data.random_split(train_data,[split,total_data - split])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_R.to(device)

train_loader = torch.utils.data.DataLoader(training_data, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(validation_data, batch_size=32, shuffle=True)


criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)
optimizer = optim.SGD(model_R.parameters(), lr=0.001, momentum=0.9)


num_epochs = 150
training_loss = []  
validation_loss = []
train_acc = []
validatoin_acc = []

#Training

for epoch in range(num_epochs):
    model_R.train()
    running_train_loss = 0.0
    train_correct = 0
    train_total = 0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model_R(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_train_loss / len(train_loader)
    train_accuary = train_correct / train_total
    training_loss.append(train_loss)
    train_acc.append(train_accuary)


#Validation

    model_R.eval()
    running_val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for i,data in enumerate(val_loader,0):
            inputs,labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_R(inputs)
            val_loss = criterion(outputs,labels)
            running_val_loss += val_loss.item()

            _,predicted = torch.max(outputs,1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()


    val_loss = running_val_loss / len(val_loader)
    val_accuracy = val_correct / val_total
    validation_loss.append(val_loss)
    validatoin_acc.append(val_accuracy)
    

    print(f"Epoch {epoch+1}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuary*100:.2f}%, Validatoin Loss: {val_loss:.4f}, Validatoin Accuracy: {val_accuracy*100:.2f}%")
    if (epoch + 1) %  10 == 0:
        torch.save(model_R.state_dict(),f"Year_model_checkpoint_epoch_{epoch + 1}.pth")

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_loss,label = 'Training')
plt.plot(range(1, num_epochs + 1), validation_loss,label = 'Validation')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_acc,color='g',label = 'Training')
plt.plot(range(1, num_epochs + 1), validatoin_acc,color='r',label = 'Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 0.7309, Training Accuracy: 51.20%, Validatoin Loss: 0.6980, Validatoin Accuracy: 53.41%
# Epoch 2, Training Loss: 0.6670, Training Accuracy: 58.89%, Validatoin Loss: 0.6327, Validatoin Accuracy: 67.47%
# Epoch 3, Training Loss: 0.6513, Training Accuracy: 61.75%, Validatoin Loss: 0.7645, Validatoin Accuracy: 50.60%
# Epoch 4, Training Loss: 0.7150, Training Accuracy: 57.83%, Validatoin Loss: 0.6416, Validatoin Accuracy: 65.66%
# Epoch 5, Training Loss: 0.6628, Training Accuracy: 61.65%, Validatoin Loss: 0.6668, Validatoin Accuracy: 59.44%
# Epoch 6, Training Loss: 0.7085, Training Accuracy: 59.29%, Validatoin Loss: 0.7840, Validatoin Accuracy: 58.03%
# Epoch 7, Training Loss: 0.6274, Training Accuracy: 65.86%, Validatoin Loss: 0.7193, Validatoin Accuracy: 62.45%
# Epoch 8, Training Loss: 0.6382, Training Accuracy: 65.66%, Validatoin Loss: 0.6361, Validatoin Accuracy: 65.06%
# Epoch 9, Training Loss: 0.6388, Training Accuracy: 64.86%, Validatoin Loss: 0.7128, Validatoin Accuracy: 61.65%
# Epoch 10, Training Loss: 0.6571, Training Accuracy: 64.66%, Validatoin Loss: 0.6057, Validatoin Accuracy: 68.67%
# Epoch 11, Training Loss: 0.6187, Training Accuracy: 65.96%, Validatoin Loss: 0.7172, Validatoin Accuracy: 61.65%
# Epoch 12, Training Loss: 0.6290, Training Accuracy: 65.51%, Validatoin Loss: 0.6178, Validatoin Accuracy: 68.88%
# Epoch 13, Training Loss: 0.6026, Training Accuracy: 67.52%, Validatoin Loss: 0.5895, Validatoin Accuracy: 69.88%
# Epoch 14, Training Loss: 0.6018, Training Accuracy: 67.87%, Validatoin Loss: 0.5829, Validatoin Accuracy: 71.49%
# Epoch 15, Training Loss: 0.6247, Training Accuracy: 66.62%, Validatoin Loss: 0.6142, Validatoin Accuracy: 68.88%
# Epoch 16, Training Loss: 0.6118, Training Accuracy: 68.07%, Validatoin Loss: 0.5969, Validatoin Accuracy: 69.08%
# Epoch 132, Training Loss: 0.0209, Training Accuracy: 99.40%, Validatoin Loss: 1.3308, Validatoin Accuracy: 77.91%
# Epoch 133, Training Loss: 0.0165, Training Accuracy: 99.45%, Validatoin Loss: 1.2636, Validatoin Accuracy: 78.51%
# Epoch 134, Training Loss: 0.0139, Training Accuracy: 99.65%, Validatoin Loss: 1.3072, Validatoin Accuracy: 78.11%
# Epoch 135, Training Loss: 0.0148, Training Accuracy: 99.55%, Validatoin Loss: 1.3385, Validatoin Accuracy: 78.71%
# Epoch 136, Training Loss: 0.0189, Training Accuracy: 99.40%, Validatoin Loss: 1.2567, Validatoin Accuracy: 78.71%
# Epoch 137, Training Loss: 0.0220, Training Accuracy: 99.20%, Validatoin Loss: 1.4003, Validatoin Accuracy: 77.31%
# Epoch 138, Training Loss: 0.0122, Training Accuracy: 99.60%, Validatoin Loss: 1.4064, Validatoin Accuracy: 79.12%
# Epoch 139, Training Loss: 0.0162, Training Accuracy: 99.20%, Validatoin Loss: 1.3750, Validatoin Accuracy: 77.91%
# Epoch 140, Training Loss: 0.0228, Training Accuracy: 99.20%, Validatoin Loss: 1.3703, Validatoin Accuracy: 78.31%
# Epoch 141, Training Loss: 0.0193, Training Accuracy: 99.40%, Validatoin Loss: 1.3746, Validatoin Accuracy: 77.51%
# Epoch 142, Training Loss: 0.0143, Training Accuracy: 99.45%, Validatoin Loss: 1.3563, Validatoin Accuracy: 78.11%
# Epoch 143, Training Loss: 0.0158, Training Accuracy: 99.50%, Validatoin Loss: 1.6095, Validatoin Accuracy: 75.70%
# Epoch 144, Training Loss: 0.0079, Training Accuracy: 99.60%, Validatoin Loss: 1.4617, Validatoin Accuracy: 78.31%
# Epoch 145, Training Loss: 0.0126, Training Accuracy: 99.50%, Validatoin Loss: 1.5174, Validatoin Accuracy: 76.10%
# Epoch 146, Training Loss: 0.0146, Training Accuracy: 99.50%, Validatoin Loss: 1.5663, Validatoin Accuracy: 78.11%
# Epoch 147, Training Loss: 0.0126, Training Accuracy: 99.60%, Validatoin Loss: 1.6437, Validatoin Accuracy: 76.31%
# Epoch 148, Training Loss: 0.0128, Training Accuracy: 99.35%, Validatoin Loss: 1.4874, Validatoin Accuracy: 79.12%
# Epoch 149, Training Loss: 0.0119, Training Accuracy: 99.45%, Validatoin Loss: 1.4380, Validatoin Accuracy: 78.71%
# Epoch 150, Training Loss: 0.0168, Training Accuracy: 99.50%, Validatoin Loss: 1.5132, Validatoin Accuracy: 77.31%

# %%
model_R.eval()
all_labels = [] 
all_scores = []  

with torch.no_grad():
    for i, data in enumerate(val_loader, 0):  # val_loader or train_loader
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model_R(inputs)

        all_labels.extend(labels.cpu().numpy())  # real label
        all_scores.extend(outputs[:, 1].cpu().numpy())  # model predict score

# Calculate AUC
fpr, tpr, thresholds = roc_curve(all_labels, all_scores)
auroc = auc(fpr, tpr)

print(f"AUROC: {auroc:.4f}")

# draw ROC
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUROC = {auroc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# AUROC: 0.8504
