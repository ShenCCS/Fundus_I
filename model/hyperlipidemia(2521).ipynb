# %%
import torch
import models_vit
import torch.nn as nn
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, auc

from pathlib import  Path
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from util.pos_embed import interpolate_pos_embed
from timm.models.layers import trunc_normal_
from torch.nn import Linear,ReLU,CrossEntropyLoss

# %%
# call the model
model_R = models_vit.__dict__['vit_large_patch16'](
    num_classes=2,
    drop_path_rate=0.2,
    global_pool=True,
)

# load RETFound weights
checkpoint = torch.load('RETFound_cfp_weights.pth', map_location='cpu')
checkpoint_model = checkpoint['model']
state_dict = model_R.state_dict()

for k in ['head.weight', 'head.bias']:
    if k in checkpoint_model and checkpoint_model[k].shape != state_dict[k].shape:
        print(f"Removing key {k} from pretrained checkpoint")
        del checkpoint_model[k]

# interpolate position embedding
interpolate_pos_embed(model_R, checkpoint_model)

# load pre-trained model
msg = model_R.load_state_dict(checkpoint_model, strict=False)

assert set(msg.missing_keys) == {'head.weight', 'head.bias', 'fc_norm.weight', 'fc_norm.bias'}

# manually initialize fc layer
trunc_normal_(model_R.head.weight, std=2e-5)

#print("Model = %s" % str(model_R))
# Out:
# Parameter containing:
# tensor([[ 1.1072e-05,  1.8045e-06, -2.9936e-05,  ..., -2.8821e-06,
#          -2.4180e-06,  2.2876e-05],
#         [-2.3392e-05, -3.4596e-05,  1.7631e-05,  ...,  9.4520e-06,
#           2.7512e-06, -3.2820e-05]], requires_grad=True)

# %%
data_transform = transforms.Compose([transforms.Resize((224, 224)),transforms.ToTensor()])
train_data = datasets.ImageFolder('/home/cluster/Fundus/RETFound_MAE-main/data/hyperlipidemia/', transform=data_transform)

total_data = len(train_data)
split = int(0.8 * total_data)

# %%
training_data, validation_data = torch.utils.data.random_split(train_data,[split,total_data - split])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model_R.to(device)

train_loader = torch.utils.data.DataLoader(training_data, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(validation_data, batch_size=32, shuffle=True)


criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)
optimizer = optim.SGD(model_R.parameters(), lr=0.001, momentum=0.9)


num_epochs = 150
training_loss = []  
validation_loss = []
train_acc = []
validatoin_acc = []

#Training

for epoch in range(num_epochs):
    model_R.train()
    running_train_loss = 0.0
    train_correct = 0
    train_total = 0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model_R(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_train_loss / len(train_loader)
    train_accuary = train_correct / train_total
    training_loss.append(train_loss)
    train_acc.append(train_accuary)


#Validation

    model_R.eval()
    running_val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for i,data in enumerate(val_loader,0):
            inputs,labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model_R(inputs)
            val_loss = criterion(outputs,labels)
            running_val_loss += val_loss.item()

            _,predicted = torch.max(outputs,1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()


    val_loss = running_val_loss / len(val_loader)
    val_accuracy = val_correct / val_total
    validation_loss.append(val_loss)
    validatoin_acc.append(val_accuracy)
    

    print(f"Epoch {epoch+1}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuary*100:.2f}%, Validatoin Loss: {val_loss:.4f}, Validatoin Accuracy: {val_accuracy*100:.2f}%")
    if (epoch + 1) %  10 == 0:
        torch.save(model_R.state_dict(),f"hyperlipidemia_model_checkpoint_epoch_{epoch + 1}.pth")

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_loss,label = 'Training')
plt.plot(range(1, num_epochs + 1), validation_loss,label = 'Validation')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_acc,color='g',label = 'Training')
plt.plot(range(1, num_epochs + 1), validatoin_acc,color='r',label = 'Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 0.2842, Training Accuracy: 92.96%, Validatoin Loss: 0.2566, Validatoin Accuracy: 92.53%
# Epoch 2, Training Loss: 0.2569, Training Accuracy: 93.03%, Validatoin Loss: 0.2535, Validatoin Accuracy: 92.53%
# Epoch 3, Training Loss: 0.2581, Training Accuracy: 93.03%, Validatoin Loss: 0.2487, Validatoin Accuracy: 92.53%
# Epoch 4, Training Loss: 0.2530, Training Accuracy: 93.03%, Validatoin Loss: 0.2940, Validatoin Accuracy: 92.53%
# Epoch 5, Training Loss: 0.2622, Training Accuracy: 93.03%, Validatoin Loss: 0.2493, Validatoin Accuracy: 92.53%
# Epoch 6, Training Loss: 0.2701, Training Accuracy: 93.03%, Validatoin Loss: 0.2548, Validatoin Accuracy: 92.53%
# Epoch 7, Training Loss: 0.2494, Training Accuracy: 93.03%, Validatoin Loss: 0.2466, Validatoin Accuracy: 92.53%
# Epoch 8, Training Loss: 0.2658, Training Accuracy: 93.03%, Validatoin Loss: 0.2433, Validatoin Accuracy: 92.53%
# Epoch 9, Training Loss: 0.2624, Training Accuracy: 93.03%, Validatoin Loss: 0.2480, Validatoin Accuracy: 92.53%
# Epoch 10, Training Loss: 0.2545, Training Accuracy: 93.03%, Validatoin Loss: 0.3153, Validatoin Accuracy: 92.53%
# Epoch 11, Training Loss: 0.2525, Training Accuracy: 93.03%, Validatoin Loss: 0.2493, Validatoin Accuracy: 92.53%
# Epoch 12, Training Loss: 0.2512, Training Accuracy: 93.03%, Validatoin Loss: 0.2520, Validatoin Accuracy: 92.53%
# Epoch 13, Training Loss: 0.2533, Training Accuracy: 93.03%, Validatoin Loss: 0.2483, Validatoin Accuracy: 92.53%
# Epoch 14, Training Loss: 0.2465, Training Accuracy: 93.03%, Validatoin Loss: 0.2557, Validatoin Accuracy: 92.53%
# Epoch 15, Training Loss: 0.2465, Training Accuracy: 93.03%, Validatoin Loss: 0.2548, Validatoin Accuracy: 92.53%
# Epoch 16, Training Loss: 0.2520, Training Accuracy: 93.03%, Validatoin Loss: 0.3357, Validatoin Accuracy: 92.53%
# Epoch 17, Training Loss: 0.2425, Training Accuracy: 93.03%, Validatoin Loss: 0.2754, Validatoin Accuracy: 92.53%
# Epoch 132, Training Loss: 0.0055, Training Accuracy: 99.87%, Validatoin Loss: 0.2515, Validatoin Accuracy: 96.39%
# Epoch 133, Training Loss: 0.0030, Training Accuracy: 99.94%, Validatoin Loss: 0.5842, Validatoin Accuracy: 95.36%
# Epoch 134, Training Loss: 0.0046, Training Accuracy: 99.81%, Validatoin Loss: 0.2891, Validatoin Accuracy: 96.39%
# Epoch 135, Training Loss: 0.0019, Training Accuracy: 100.00%, Validatoin Loss: 0.4454, Validatoin Accuracy: 95.88%
# Epoch 136, Training Loss: 0.0025, Training Accuracy: 99.94%, Validatoin Loss: 0.1809, Validatoin Accuracy: 96.91%
# Epoch 137, Training Loss: 0.0173, Training Accuracy: 99.42%, Validatoin Loss: 0.1770, Validatoin Accuracy: 94.33%
# Epoch 138, Training Loss: 0.0318, Training Accuracy: 98.97%, Validatoin Loss: 0.5543, Validatoin Accuracy: 96.91%
# Epoch 139, Training Loss: 0.0157, Training Accuracy: 99.42%, Validatoin Loss: 0.2315, Validatoin Accuracy: 96.65%
# Epoch 140, Training Loss: 0.0115, Training Accuracy: 99.68%, Validatoin Loss: 0.1986, Validatoin Accuracy: 97.42%
# Epoch 141, Training Loss: 0.0175, Training Accuracy: 99.42%, Validatoin Loss: 0.1169, Validatoin Accuracy: 97.16%
# Epoch 142, Training Loss: 0.0158, Training Accuracy: 99.42%, Validatoin Loss: 0.2367, Validatoin Accuracy: 96.39%
# Epoch 143, Training Loss: 0.0043, Training Accuracy: 99.87%, Validatoin Loss: 0.1170, Validatoin Accuracy: 97.68%
# Epoch 144, Training Loss: 0.0110, Training Accuracy: 99.68%, Validatoin Loss: 0.1724, Validatoin Accuracy: 96.91%
# Epoch 145, Training Loss: 0.0024, Training Accuracy: 100.00%, Validatoin Loss: 0.2168, Validatoin Accuracy: 96.91%
# Epoch 146, Training Loss: 0.0018, Training Accuracy: 99.94%, Validatoin Loss: 0.2766, Validatoin Accuracy: 96.13%
# Epoch 147, Training Loss: 0.0097, Training Accuracy: 99.74%, Validatoin Loss: 0.2268, Validatoin Accuracy: 96.65%
# Epoch 148, Training Loss: 0.0078, Training Accuracy: 99.68%, Validatoin Loss: 0.5954, Validatoin Accuracy: 94.85%
# Epoch 149, Training Loss: 0.0063, Training Accuracy: 99.81%, Validatoin Loss: 0.2747, Validatoin Accuracy: 95.88%
# Epoch 150, Training Loss: 0.0048, Training Accuracy: 99.81%, Validatoin Loss: 0.2601, Validatoin Accuracy: 96.13%

# %%
model_R.eval()
all_labels = [] 
all_scores = []  

with torch.no_grad():
    for i, data in enumerate(val_loader, 0):  # val_loader or train_loader
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model_R(inputs)

        all_labels.extend(labels.cpu().numpy())  # real label
        all_scores.extend(outputs[:, 1].cpu().numpy())  # model predict score

# Calculate AUC
fpr, tpr, thresholds = roc_curve(all_labels, all_scores)
auroc = auc(fpr, tpr)

print(f"AUROC: {auroc:.4f}")

# draw ROC
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUROC = {auroc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# AUROC: 0.9698
